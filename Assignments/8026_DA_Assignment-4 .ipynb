# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# 1. Write a Pandas program to read a csv file from a specified source and print the
# first 5 rows.(Diamonds.csv)
df = sns.load_dataset('diamonds')
df.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#2. Write a Pandas program to read a dataset from diamonds DataFrame and
# modify the default columns values and print the first 6 rows.
print(df.columns)
df=df.rename(columns={
    'carat': 'Carat_Weight',
    'cut': 'Cut_Quality',
    'color': 'Color_Grade',
    'clarity': 'Clarity_Grade',
    'price': 'Price_USD',
    'x': 'Length_mm',
    'y': 'Width_mm',
    'z': 'Depth_mm'
})
df.head(6)
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')
#    Carat_Weight Cut_Quality Color_Grade Clarity_Grade  depth  table  \
# 0          0.23       Ideal           E           SI2   61.5   55.0
# 1          0.21     Premium           E           SI1   59.8   61.0
# 2          0.23        Good           E           VS1   56.9   65.0
# 3          0.29     Premium           I           VS2   62.4   58.0
# 4          0.31        Good           J           SI2   63.3   58.0
# 5          0.24   Very Good           J          VVS2   62.8   57.0
#
#    Price_USD  Length_mm  Width_mm  Depth_mm
# 0        326       3.95      3.98      2.43
# 1        326       3.89      3.84      2.31
# 2        327       4.05      4.07      2.31
# 3        334       4.20      4.23      2.63
# 4        335       4.34      4.35      2.75
# 5        336       3.94      3.96      2.48

# %%
#3. Write a Pandas program to select a series from diamonds DataFrame. Print
#the content of the series.
carat_series = df['Carat_Weight']
print("Carat Series:")
print(carat_series.head(10))
# Out:
# Carat Series:
# 0    0.23
# 1    0.21
# 2    0.23
# 3    0.29
# 4    0.31
# 5    0.24
# 6    0.24
# 7    0.26
# 8    0.22
# 9    0.23
# Name: Carat_Weight, dtype: float64

# %%
#4. Write a Pandas program to create a new 'Quality -color' Series (use bracket
#notation to define the Series name) of the diamonds DataFrame.
df['Quality -color'] = df['Cut_Quality'].astype(str) + " - " + df['Color_Grade'].astype(str)
df
# Out:
#        Carat_Weight Cut_Quality Color_Grade Clarity_Grade  depth  table  \
# 0              0.23       Ideal           E           SI2   61.5   55.0
# 1              0.21     Premium           E           SI1   59.8   61.0
# 2              0.23        Good           E           VS1   56.9   65.0
# 3              0.29     Premium           I           VS2   62.4   58.0
# 4              0.31        Good           J           SI2   63.3   58.0
# ...             ...         ...         ...           ...    ...    ...
# 53935          0.72       Ideal           D           SI1   60.8   57.0
# 53936          0.72        Good           D           SI1   63.1   55.0
# 53937          0.70   Very Good           D           SI1   62.8   60.0
# 53938          0.86     Premium           H           SI2   61.0   58.0
# 53939          0.75       Ideal           D           SI2   62.2   55.0
#
#        Price_USD  Length_mm  Width_mm  Depth_mm Quality -color
# 0            326       3.95      3.98      2.43      Ideal - E
# 1            326       3.89      3.84      2.31    Premium - E
# 2            327       4.05      4.07      2.31       Good - E
# 3            334       4.20      4.23      2.63    Premium - I
# 4            335       4.34      4.35      2.75       Good - J
# ...          ...        ...       ...       ...            ...
# 53935       2757       5.75      5.76      3.50      Ideal - D
# 53936       2757       5.69      5.75      3.61       Good - D
# 53937       2757       5.66      5.68      3.56  Very Good - D
# 53938       2757       6.15      6.12      3.74    Premium - H
# 53939       2757       5.83      5.87      3.64      Ideal - D
#
# [53940 rows x 11 columns]

# %%
# 5. Write a Pandas program to find the number of rows and columns and data
# type of each column of diamonds Dataframe.
print("Shape of datafame (Rows x Columns) :",df.shape)
print(df.dtypes)
# Out:
# Shape of datafame (Rows x Columns) : (53940, 11)
# Carat_Weight       float64
# Cut_Quality       category
# Color_Grade       category
# Clarity_Grade     category
# depth              float64
# table              float64
# Price_USD            int64
# Length_mm          float64
# Width_mm           float64
# Depth_mm           float64
# Quality -color      object
# dtype: object

# %%
# 6. Write a Pandas program to summarize only 'object' columns of the diamonds
# Dataframe.
df.describe(include=['category'])
# Out:
#        Cut_Quality Color_Grade Clarity_Grade
# count        53940       53940         53940
# unique           5           7             8
# top          Ideal           G           SI1
# freq         21551       11292         13065

# %%
# 7. Write a Pandas program to rename two of the columns of the diamonds
# Dataframe.
print(df.head())
df=df.rename(columns={'color':'color_Grade','clarity':'clarity_Grade'})
df
# Out:
#    Carat_Weight Cut_Quality Color_Grade Clarity_Grade  depth  table  \
# 0          0.23       Ideal           E           SI2   61.5   55.0
# 1          0.21     Premium           E           SI1   59.8   61.0
# 2          0.23        Good           E           VS1   56.9   65.0
# 3          0.29     Premium           I           VS2   62.4   58.0
# 4          0.31        Good           J           SI2   63.3   58.0
#
#    Price_USD  Length_mm  Width_mm  Depth_mm Quality -color
# 0        326       3.95      3.98      2.43      Ideal - E
# 1        326       3.89      3.84      2.31    Premium - E
# 2        327       4.05      4.07      2.31       Good - E
# 3        334       4.20      4.23      2.63    Premium - I
# 4        335       4.34      4.35      2.75       Good - J
#        Carat_Weight Cut_Quality Color_Grade Clarity_Grade  depth  table  \
# 0              0.23       Ideal           E           SI2   61.5   55.0
# 1              0.21     Premium           E           SI1   59.8   61.0
# 2              0.23        Good           E           VS1   56.9   65.0
# 3              0.29     Premium           I           VS2   62.4   58.0
# 4              0.31        Good           J           SI2   63.3   58.0
# ...             ...         ...         ...           ...    ...    ...
# 53935          0.72       Ideal           D           SI1   60.8   57.0
# 53936          0.72        Good           D           SI1   63.1   55.0
# 53937          0.70   Very Good           D           SI1   62.8   60.0
# 53938          0.86     Premium           H           SI2   61.0   58.0
# 53939          0.75       Ideal           D           SI2   62.2   55.0
#
#        Price_USD  Length_mm  Width_mm  Depth_mm Quality -color
# 0            326       3.95      3.98      2.43      Ideal - E
# 1            326       3.89      3.84      2.31    Premium - E
# 2            327       4.05      4.07      2.31       Good - E
# 3            334       4.20      4.23      2.63    Premium - I
# 4            335       4.34      4.35      2.75       Good - J
# ...          ...        ...       ...       ...            ...
# 53935       2757       5.75      5.76      3.50      Ideal - D
# 53936       2757       5.69      5.75      3.61       Good - D
# 53937       2757       5.66      5.68      3.56  Very Good - D
# 53938       2757       6.15      6.12      3.74    Premium - H
# 53939       2757       5.83      5.87      3.64      Ideal - D
#
# [53940 rows x 11 columns]

# %%
# 8. Write a Pandas program to rename all the columns of the diamonds
# Dataframe.
df=df.rename(columns={
    'carat': 'Carat_Weight',
    'cut': 'Cut_Quality',
    'color': 'Color_Grade',
    'clarity': 'Clarity_Grade',
    'price': 'Price_USD',
    'x': 'Length_mm',
    'y': 'Width_mm',
    'z': 'Depth_mm'
})
df
# Out:
#        Carat_Weight Cut_Quality Color_Grade Clarity_Grade  depth  table  \
# 0              0.23       Ideal           E           SI2   61.5   55.0
# 1              0.21     Premium           E           SI1   59.8   61.0
# 2              0.23        Good           E           VS1   56.9   65.0
# 3              0.29     Premium           I           VS2   62.4   58.0
# 4              0.31        Good           J           SI2   63.3   58.0
# ...             ...         ...         ...           ...    ...    ...
# 53935          0.72       Ideal           D           SI1   60.8   57.0
# 53936          0.72        Good           D           SI1   63.1   55.0
# 53937          0.70   Very Good           D           SI1   62.8   60.0
# 53938          0.86     Premium           H           SI2   61.0   58.0
# 53939          0.75       Ideal           D           SI2   62.2   55.0
#
#        Price_USD  Length_mm  Width_mm  Depth_mm Quality -color
# 0            326       3.95      3.98      2.43      Ideal - E
# 1            326       3.89      3.84      2.31    Premium - E
# 2            327       4.05      4.07      2.31       Good - E
# 3            334       4.20      4.23      2.63    Premium - I
# 4            335       4.34      4.35      2.75       Good - J
# ...          ...        ...       ...       ...            ...
# 53935       2757       5.75      5.76      3.50      Ideal - D
# 53936       2757       5.69      5.75      3.61       Good - D
# 53937       2757       5.66      5.68      3.56  Very Good - D
# 53938       2757       6.15      6.12      3.74    Premium - H
# 53939       2757       5.83      5.87      3.64      Ideal - D
#
# [53940 rows x 11 columns]

# %%
df
# Out:
#        Carat_Weight Cut_Quality Color_Grade Clarity_Grade  depth  table  \
# 0              0.23       Ideal           E           SI2   61.5   55.0
# 1              0.21     Premium           E           SI1   59.8   61.0
# 2              0.23        Good           E           VS1   56.9   65.0
# 3              0.29     Premium           I           VS2   62.4   58.0
# 4              0.31        Good           J           SI2   63.3   58.0
# ...             ...         ...         ...           ...    ...    ...
# 53935          0.72       Ideal           D           SI1   60.8   57.0
# 53936          0.72        Good           D           SI1   63.1   55.0
# 53937          0.70   Very Good           D           SI1   62.8   60.0
# 53938          0.86     Premium           H           SI2   61.0   58.0
# 53939          0.75       Ideal           D           SI2   62.2   55.0
#
#        Price_USD  Length_mm  Width_mm  Depth_mm Quality -color
# 0            326       3.95      3.98      2.43      Ideal - E
# 1            326       3.89      3.84      2.31    Premium - E
# 2            327       4.05      4.07      2.31       Good - E
# 3            334       4.20      4.23      2.63    Premium - I
# 4            335       4.34      4.35      2.75       Good - J
# ...          ...        ...       ...       ...            ...
# 53935       2757       5.75      5.76      3.50      Ideal - D
# 53936       2757       5.69      5.75      3.61       Good - D
# 53937       2757       5.66      5.68      3.56  Very Good - D
# 53938       2757       6.15      6.12      3.74    Premium - H
# 53939       2757       5.83      5.87      3.64      Ideal - D
#
# [53940 rows x 11 columns]

# %%
# 9. Write a Pandas program to remove the second column of the diamonds
# Dataframe.
df = df.drop(df.columns[1], axis=1)
df
# Out:
#        Carat_Weight Color_Grade Clarity_Grade  depth  table  Price_USD  \
# 0              0.23           E           SI2   61.5   55.0        326
# 1              0.21           E           SI1   59.8   61.0        326
# 2              0.23           E           VS1   56.9   65.0        327
# 3              0.29           I           VS2   62.4   58.0        334
# 4              0.31           J           SI2   63.3   58.0        335
# ...             ...         ...           ...    ...    ...        ...
# 53935          0.72           D           SI1   60.8   57.0       2757
# 53936          0.72           D           SI1   63.1   55.0       2757
# 53937          0.70           D           SI1   62.8   60.0       2757
# 53938          0.86           H           SI2   61.0   58.0       2757
# 53939          0.75           D           SI2   62.2   55.0       2757
#
#        Length_mm  Width_mm  Depth_mm Quality -color
# 0           3.95      3.98      2.43      Ideal - E
# 1           3.89      3.84      2.31    Premium - E
# 2           4.05      4.07      2.31       Good - E
# 3           4.20      4.23      2.63    Premium - I
# 4           4.34      4.35      2.75       Good - J
# ...          ...       ...       ...            ...
# 53935       5.75      5.76      3.50      Ideal - D
# 53936       5.69      5.75      3.61       Good - D
# 53937       5.66      5.68      3.56  Very Good - D
# 53938       6.15      6.12      3.74    Premium - H
# 53939       5.83      5.87      3.64      Ideal - D
#
# [53940 rows x 10 columns]

# %%
# 10. Write a Pandas program to remove multiple columns at once of the diamonds
# Dataframe.
df = df.drop(df.columns[[1,2]], axis=1)
df
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm  \
# 0              0.23   61.5   55.0        326       3.95      3.98      2.43
# 1              0.21   59.8   61.0        326       3.89      3.84      2.31
# 2              0.23   56.9   65.0        327       4.05      4.07      2.31
# 3              0.29   62.4   58.0        334       4.20      4.23      2.63
# 4              0.31   63.3   58.0        335       4.34      4.35      2.75
# ...             ...    ...    ...        ...        ...       ...       ...
# 53935          0.72   60.8   57.0       2757       5.75      5.76      3.50
# 53936          0.72   63.1   55.0       2757       5.69      5.75      3.61
# 53937          0.70   62.8   60.0       2757       5.66      5.68      3.56
# 53938          0.86   61.0   58.0       2757       6.15      6.12      3.74
# 53939          0.75   62.2   55.0       2757       5.83      5.87      3.64
#
#       Quality -color
# 0          Ideal - E
# 1        Premium - E
# 2           Good - E
# 3        Premium - I
# 4           Good - J
# ...              ...
# 53935      Ideal - D
# 53936       Good - D
# 53937  Very Good - D
# 53938    Premium - H
# 53939      Ideal - D
#
# [53940 rows x 8 columns]

# %%
# 11. Write a Pandas program to remove multiple rows at once (axis=0 refers to
# rows) from diamonds dataframe.
df=df.drop([1,2,3],axis=0)
df
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm  \
# 0              0.23   61.5   55.0        326       3.95      3.98      2.43
# 4              0.31   63.3   58.0        335       4.34      4.35      2.75
# 5              0.24   62.8   57.0        336       3.94      3.96      2.48
# 6              0.24   62.3   57.0        336       3.95      3.98      2.47
# 7              0.26   61.9   55.0        337       4.07      4.11      2.53
# ...             ...    ...    ...        ...        ...       ...       ...
# 53935          0.72   60.8   57.0       2757       5.75      5.76      3.50
# 53936          0.72   63.1   55.0       2757       5.69      5.75      3.61
# 53937          0.70   62.8   60.0       2757       5.66      5.68      3.56
# 53938          0.86   61.0   58.0       2757       6.15      6.12      3.74
# 53939          0.75   62.2   55.0       2757       5.83      5.87      3.64
#
#       Quality -color
# 0          Ideal - E
# 4           Good - J
# 5      Very Good - J
# 6      Very Good - I
# 7      Very Good - H
# ...              ...
# 53935      Ideal - D
# 53936       Good - D
# 53937  Very Good - D
# 53938    Premium - H
# 53939      Ideal - D
#
# [53937 rows x 8 columns]

# %%
# 12. Write a Pandas program to sort the 'cut' Series in ascending order (returns a
# Series) of diamonds Dataframe.
sorted_cut = df['Quality -color'].sort_values(ascending=True)
sorted_cut
# Out:
# 8276          Fair - D
# 39713         Fair - D
# 9980          Fair - D
# 11910         Fair - D
# 2959          Fair - D
#              ...
# 25061    Very Good - J
# 25072    Very Good - J
# 25076    Very Good - J
# 13408    Very Good - J
# 15783    Very Good - J
# Name: Quality -color, Length: 53937, dtype: object

# %%
# 13. Write a Pandas program to sort the 'price' Series in descending order (returns
# a Series) of diamonds Dataframe.
sorted_price=df['Price_USD'].sort_values(ascending=False)
sorted_price
# Out:
# 27749    18823
# 27748    18818
# 27747    18806
# 27746    18804
# 27745    18803
#          ...
# 7          337
# 5          336
# 6          336
# 4          335
# 0          326
# Name: Price_USD, Length: 53937, dtype: int64

# %%
# 14. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat'
# Series in ascending and descending order.
df=df.sort_values(by='Carat_Weight',ascending=True)
df
df=df.sort_values(by='Carat_Weight',ascending=False)
df
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm  \
# 27415          5.01   65.5   59.0      18018      10.74     10.54      6.98
# 27630          4.50   65.8   58.0      18531      10.23     10.16      6.72
# 27130          4.13   64.8   61.0      17329      10.00      9.85      6.43
# 25999          4.01   62.5   62.0      15223      10.02      9.94      6.24
# 25998          4.01   61.0   61.0      15223      10.14     10.10      6.17
# ...             ...    ...    ...        ...        ...       ...       ...
# 31601          0.20   61.7   60.0        367       3.77      3.72      2.31
# 31598          0.20   63.4   59.0        367       3.74      3.71      2.36
# 14             0.20   60.2   62.0        345       3.79      3.75      2.27
# 31599          0.20   62.2   57.0        367       3.76      3.73      2.33
# 31594          0.20   59.7   62.0        367       3.84      3.80      2.28
#
#       Quality -color
# 27415       Fair - J
# 27630       Fair - J
# 27130       Fair - H
# 25999    Premium - J
# 25998    Premium - I
# ...              ...
# 31601    Premium - D
# 31598  Very Good - E
# 14       Premium - E
# 31599      Ideal - E
# 31594    Premium - E
#
# [53937 rows x 8 columns]

# %%
# 15. Write a Pandas program to filter the DataFrame rows to only show carat
# weight at least 0.3.
df[df['Carat_Weight']>=0.3]
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm  \
# 27415          5.01   65.5   59.0      18018      10.74     10.54      6.98
# 27630          4.50   65.8   58.0      18531      10.23     10.16      6.72
# 27130          4.13   64.8   61.0      17329      10.00      9.85      6.43
# 25999          4.01   62.5   62.0      15223      10.02      9.94      6.24
# 25998          4.01   61.0   61.0      15223      10.14     10.10      6.17
# ...             ...    ...    ...        ...        ...       ...       ...
# 36657          0.30   61.3   57.0        949       4.30      4.32      2.64
# 10030          0.30   64.8   58.0        416       4.24      4.16      2.72
# 29300          0.30   60.3   57.0        438       4.36      4.39      2.64
# 10025          0.30   60.8   65.0        414       4.26      4.29      2.60
# 36658          0.30   61.4   55.0        949       4.33      4.36      2.67
#
#       Quality -color
# 27415       Fair - J
# 27630       Fair - J
# 27130       Fair - H
# 25999    Premium - J
# 25998    Premium - I
# ...              ...
# 36657      Ideal - E
# 10030       Fair - J
# 29300      Ideal - I
# 10025       Good - D
# 36658      Ideal - E
#
# [52341 rows x 8 columns]

# %%
# 16. Write a Pandas program to convert a python list to pandas series.
list1=[1,2,3,4,5]
series=pd.Series(list1)
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# 17. Write a Pandas program to find the details of the diamonds where length>5,
# width>5 and depth>5.
df[(df['Length_mm']>5)&(df['Width_mm']>5)&(df['Depth_mm']>5)]
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm  \
# 27415          5.01   65.5   59.0      18018      10.74     10.54      6.98
# 27630          4.50   65.8   58.0      18531      10.23     10.16      6.72
# 27130          4.13   64.8   61.0      17329      10.00      9.85      6.43
# 25999          4.01   62.5   62.0      15223      10.02      9.94      6.24
# 25998          4.01   61.0   61.0      15223      10.14     10.10      6.17
# ...             ...    ...    ...        ...        ...       ...       ...
# 14881          1.82   67.3   58.0       5993       7.50      7.47      5.04
# 14504          1.81   68.0   57.0       5859       7.43      7.39      5.04
# 48410          0.51   61.8   54.7       1970       5.12      5.15     31.80
# 49189          0.51   61.8   55.0       2075       5.15     31.80      5.12
# 49905          0.50   63.7   58.0       2180       5.01      5.04      5.06
#
#       Quality -color
# 27415       Fair - J
# 27630       Fair - J
# 27130       Fair - H
# 25999    Premium - J
# 25998    Premium - I
# ...              ...
# 14881       Fair - H
# 14504       Fair - J
# 48410  Very Good - E
# 49189      Ideal - E
# 49905  Very Good - G
#
# [1457 rows x 8 columns]

# %%
# 18. Write a Pandas program to find the diamonds that are either Premium or
# Ideal.
premium_ideal = df[df['Quality -color'].isin(['Premium - J', 'Ideal - E'])]
#actual column is deleted hence working on Quality -color 
premium_ideal
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm  \
# 25999          4.01   62.5   62.0      15223      10.02      9.94      6.24
# 27679          3.51   62.5   59.0      18701       9.66      9.63      6.03
# 27684          3.01   60.7   59.0      18710       9.35      9.22      5.64
# 27685          3.01   59.7   58.0      18710       9.41      9.32      5.59
# 22578          2.63   62.3   61.0      10628       8.81      8.76      5.47
# ...             ...    ...    ...        ...        ...       ...       ...
# 47650          0.23   62.5   57.0        530       3.92      3.99      2.47
# 8711           0.23   61.9   55.0        586       3.94      3.98      2.45
# 8712           0.23   61.5   54.0        586       3.96      3.97      2.44
# 31595          0.20   59.7   55.0        367       3.86      3.84      2.30
# 31599          0.20   62.2   57.0        367       3.76      3.73      2.33
#
#       Quality -color
# 25999    Premium - J
# 27679    Premium - J
# 27684    Premium - J
# 27685    Premium - J
# 22578    Premium - J
# ...              ...
# 47650      Ideal - E
# 8711       Ideal - E
# 8712       Ideal - E
# 31595      Ideal - E
# 31599      Ideal - E
#
# [4711 rows x 8 columns]

# %%
# 19. Write a Pandas program to find the diamonds that are with a Fair or Good or
# Premium.
fair_good = df[df['Quality -color'].isin(['Fair - J', 'Good - E','Premium - J'])]
fair_good
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm  \
# 27415          5.01   65.5   59.0      18018      10.74     10.54      6.98
# 27630          4.50   65.8   58.0      18531      10.23     10.16      6.72
# 25999          4.01   62.5   62.0      15223      10.02      9.94      6.24
# 27679          3.51   62.5   59.0      18701       9.66      9.63      6.03
# 21758          3.11   65.9   57.0       9823       9.15      9.02      5.98
# ...             ...    ...    ...        ...        ...       ...       ...
# 32630          0.23   60.6   65.0        458       3.95      3.97      2.40
# 47663          0.23   63.3   56.0        530       3.88      3.92      2.47
# 36             0.23   64.1   59.0        402       3.83      3.85      2.46
# 42288          0.23   62.2   60.0        505       3.90      3.94      2.44
# 37926          0.23   63.4   61.0        485       3.85      3.91      2.46
#
#       Quality -color
# 27415       Fair - J
# 27630       Fair - J
# 25999    Premium - J
# 27679    Premium - J
# 21758       Fair - J
# ...              ...
# 32630       Good - E
# 47663       Good - E
# 36          Good - E
# 42288       Good - E
# 37926       Good - E
#
# [1859 rows x 8 columns]

# %%
#20. Write a Pandas program to display all column labels of diamonds DataFrame.
df.columns
# Out:
# Index(['Carat_Weight', 'depth', 'table', 'Price_USD', 'Length_mm', 'Width_mm',
#        'Depth_mm', 'Quality -color'],
#       dtype='object')

# %%
# 21. Write a Pandas program to read only a subset of 3 rows from diamonds
# DataFrame.
df.head(3)
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm  \
# 27415          5.01   65.5   59.0      18018      10.74     10.54      6.98
# 27630          4.50   65.8   58.0      18531      10.23     10.16      6.72
# 27130          4.13   64.8   61.0      17329      10.00      9.85      6.43
#
#       Quality -color
# 27415       Fair - J
# 27630       Fair - J
# 27130       Fair - H

# %%
#22. Write a Pandas program to iterate through diamonds DataFrame.
for index, row in df.head(5).iterrows():
    print(row , end=' ')
# Out:
# Carat_Weight          5.01
# depth                 65.5
# table                 59.0
# Price_USD            18018
# Length_mm            10.74
# Width_mm             10.54
# Depth_mm              6.98
# Quality -color    Fair - J
# Name: 27415, dtype: object Carat_Weight           4.5
# depth                 65.8
# table                 58.0
# Price_USD            18531
# Length_mm            10.23
# Width_mm             10.16
# Depth_mm              6.72
# Quality -color    Fair - J
# Name: 27630, dtype: object Carat_Weight          4.13
# depth                 64.8
# table                 61.0
# Price_USD            17329
# Length_mm             10.0
# Width_mm              9.85
# Depth_mm              6.43
# Quality -color    Fair - H
# Name: 27130, dtype: object Carat_Weight             4.01
# depth                    62.5
# table                    62.0
# Price_USD               15223
# Length_mm               10.02
# Width_mm                 9.94
# Depth_mm                 6.24
# Quality -color    Premium - J
# Name: 25999, dtype: object Carat_Weight             4.01
# depth                    61.0
# table                    61.0
# Price_USD               15223
# Length_mm               10.14
# Width_mm                 10.1
# Depth_mm                 6.17
# Quality -color    Premium - I
# Name: 25998, dtype: object

# %%
# 23. Write a Pandas program to drop all non-numeric columns from diamonds
# DataFrame.
df_numeric = df.select_dtypes(include=['number'])
df_numeric
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm
# 27415          5.01   65.5   59.0      18018      10.74     10.54      6.98
# 27630          4.50   65.8   58.0      18531      10.23     10.16      6.72
# 27130          4.13   64.8   61.0      17329      10.00      9.85      6.43
# 25999          4.01   62.5   62.0      15223      10.02      9.94      6.24
# 25998          4.01   61.0   61.0      15223      10.14     10.10      6.17
# ...             ...    ...    ...        ...        ...       ...       ...
# 31601          0.20   61.7   60.0        367       3.77      3.72      2.31
# 31598          0.20   63.4   59.0        367       3.74      3.71      2.36
# 14             0.20   60.2   62.0        345       3.79      3.75      2.27
# 31599          0.20   62.2   57.0        367       3.76      3.73      2.33
# 31594          0.20   59.7   62.0        367       3.84      3.80      2.28
#
# [53937 rows x 7 columns]

# %%
# 24. Write a Pandas program to include only numeric columns in the diamonds
# DataFrame.
df_numeric = df.select_dtypes(include=['number'])
df_numeric
# Out:
#        Carat_Weight  depth  table  Price_USD  Length_mm  Width_mm  Depth_mm
# 27415          5.01   65.5   59.0      18018      10.74     10.54      6.98
# 27630          4.50   65.8   58.0      18531      10.23     10.16      6.72
# 27130          4.13   64.8   61.0      17329      10.00      9.85      6.43
# 25999          4.01   62.5   62.0      15223      10.02      9.94      6.24
# 25998          4.01   61.0   61.0      15223      10.14     10.10      6.17
# ...             ...    ...    ...        ...        ...       ...       ...
# 31601          0.20   61.7   60.0        367       3.77      3.72      2.31
# 31598          0.20   63.4   59.0        367       3.74      3.71      2.36
# 14             0.20   60.2   62.0        345       3.79      3.75      2.27
# 31599          0.20   62.2   57.0        367       3.76      3.73      2.33
# 31594          0.20   59.7   62.0        367       3.84      3.80      2.28
#
# [53937 rows x 7 columns]

# %%
# 25. Write a Pandas program to pass a list of data types to only describe certain
# types of diamonds DataFrame.
summary = df.describe(include=['number', 'category'])
summary
# Out:
#        Carat_Weight         depth         table     Price_USD     Length_mm  \
# count  53937.000000  53937.000000  53937.000000  53937.000000  53937.000000
# mean       0.797971     61.749519     57.456968   3933.000167      5.731251
# std        0.474006      1.432482      2.234263   3989.460146      1.121721
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5325.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#            Width_mm      Depth_mm
# count  53937.000000  53937.000000
# mean       5.734620      3.538796
# std        1.142096      0.705668
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
# 26. Write a Pandas program to calculate the mean of each numeric column of
# diamonds DataFrame.
mean_values = df.mean(numeric_only=True)
mean_values
# Out:
# Carat_Weight       0.797971
# depth             61.749519
# table             57.456968
# Price_USD       3933.000167
# Length_mm          5.731251
# Width_mm           5.734620
# Depth_mm           3.538796
# dtype: float64

# %%
# 27. Write a Pandas program to calculate the mean of each row of diamonds
# DataFrame.
mean_row=df.mean(axis=1,numeric_only=True)
mean_row
# Out:
# 27415    2596.538571
# 27630    2669.487143
# 27130    2497.887143
# 25999    2196.815714
# 25998    2196.488571
#             ...
# 31601      71.242857
# 31598      71.344286
# 14         68.172857
# 31599      70.888571
# 31594      71.260000
# Length: 53937, dtype: float64

# %%
# 28. Write a Pandas program to calculate the mean of price for each cut of
# diamonds DataFrame.
df.groupby('Quality -color')['Price_USD'].mean()
# Out:
# Quality -color
# Fair - D         4291.061350
# Fair - E         3682.312500
# Fair - F         3827.003205
# Fair - G         4239.254777
# Fair - H         5135.683168
# Fair - I         4685.445714
# Fair - J         4975.655462
# Good - D         3405.382175
# Good - E         3426.966738
# Good - F         3495.750275
# Good - G         4123.482204
# Good - H         4276.254986
# Good - I         5078.532567
# Good - J         4574.172638
# Ideal - D        2629.094566
# Ideal - E        2597.550090
# Ideal - F        3374.939362
# Ideal - G        3720.706388
# Ideal - H        3889.334831
# Ideal - I        4451.970377
# Ideal - J        4918.186384
# Premium - D      3631.292576
# Premium - E      3540.289812
# Premium - F      4324.890176
# Premium - G      4500.742134
# Premium - H      5216.706780
# Premium - I      5950.113525
# Premium - J      6294.591584
# Very Good - D    3470.467284
# Very Good - E    3214.652083
# Very Good - F    3778.820240
# Very Good - G    3872.753806
# Very Good - H    4535.390351
# Very Good - I    5255.879568
# Very Good - J    5103.513274
# Name: Price_USD, dtype: float64

# %%
#29. Write a Pandas program to calculate count, minimum, maximum price for
# each cut of diamonds DataFrame.
print("\nCount of Cut Quality :\n")
print(df.groupby('Quality -color')['Price_USD'].count())
print("\nmin price of each Cut Quality :\n")
print(df.groupby('Quality -color')['Price_USD'].min())
print("\nmax price of each Cut Quality :\n")
print(df.groupby('Quality -color')['Price_USD'].max())
# Out:
# Count of Cut Quality :
#
# Quality -color
# Fair - D          163
# Fair - E          224
# Fair - F          312
# Fair - G          314
# Fair - H          303
# Fair - I          175
# Fair - J          119
# Good - D          662
# Good - E          932
# Good - F          909
# Good - G          871
# Good - H          702
# Good - I          522
# Good - J          307
# Ideal - D        2834
# Ideal - E        3903
# Ideal - F        3826
# Ideal - G        4884
# Ideal - H        3115
# Ideal - I        2093
# Ideal - J         896
# Premium - D      1603
# Premium - E      2336
# Premium - F      2331
# Premium - G      2924
# Premium - H      2360
# Premium - I      1427
# Premium - J       808
# Very Good - D    1513
# Very Good - E    2400
# Very Good - F    2164
# Very Good - G    2299
# Very Good - H    1824
# Very Good - I    1204
# Very Good - J     678
# Name: Price_USD, dtype: int64
#
# min price of each Cut Quality :
#
# Quality -color
# Fair - D         536
# Fair - E         337
# Fair - F         496
# Fair - G         369
# Fair - H         659
# Fair - I         735
# Fair - J         416
# Good - D         361
# Good - E         357
# Good - F         357
# Good - G         394
# Good - H         368
# Good - I         351
# Good - J         335
# Ideal - D        367
# Ideal - E        326
# Ideal - F        408
# Ideal - G        361
# Ideal - H        357
# Ideal - I        348
# Ideal - J        340
# Premium - D      367
# Premium - E      345
# Premium - F      342
# Premium - G      382
# Premium - H      368
# Premium - I      355
# Premium - J      363
# Very Good - D    357
# Very Good - E    352
# Very Good - F    357
# Very Good - G    354
# Very Good - H    337
# Very Good - I    336
# Very Good - J    336
# Name: Price_USD, dtype: int64
#
# max price of each Cut Quality :
#
# Quality -color
# Fair - D         16386
# Fair - E         15584
# Fair - F         17995
# Fair - G         18574
# Fair - H         18565
# Fair - I         18242
# Fair - J         18531
# Good - D         18468
# Good - E         18236
# Good - F         18686
# Good - G         18788
# Good - H         18640
# Good - I         18707
# Good - J         18325
# Ideal - D        18693
# Ideal - E        18729
# Ideal - F        18780
# Ideal - G        18806
# Ideal - H        18760
# Ideal - I        18779
# Ideal - J        18508
# Premium - D      18575
# Premium - E      18477
# Premium - F      18791
# Premium - G      18741
# Premium - H      18795
# Premium - I      18823
# Premium - J      18710
# Very Good - D    18542
# Very Good - E    18731
# Very Good - F    18777
# Very Good - G    18818
# Very Good - H    18803
# Very Good - I    18500
# Very Good - J    18430
# Name: Price_USD, dtype: int64

# %%
# 30. Write a Pandas program to create a side-by-side bar plot of the diamonds
# DataFrame.
import seaborn as sns 
import matplotlib.pyplot as plt

df = sns.load_dataset('diamonds')

plt.figure(figsize=(12,6))
sns.barplot(
    data=df,
    x="cut",       
    y="price",     
    hue="color",   
)
plt.xlabel("Cut")
plt.ylabel("Price")
plt.legend()
plt.title("Cut vs Price")
plt.show()

# %%
#31. Write a Pandas program to count how many times each value in cut series of
# diamonds DataFrame occurs.
cut_counts = df['cut'].value_counts()
cut_counts
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
# 32. Write a Pandas program to display percentages of each value of cut series
# occurs in diamonds DataFrame.
total=len(df)
cut_pc = (df['cut'].value_counts() /total)*100
cut_pc
# Out:
# cut
# Ideal        39.953652
# Premium      25.567297
# Very Good    22.398962
# Good          9.095291
# Fair          2.984798
# Name: count, dtype: float64

# %%
# 33. Write a Pandas program to display the unique values in cut series of
# diamonds DataFrame.
unique_cuts = df['cut'].unique()
unique_cuts
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
# 34. Write a Pandas program to count the number of unique values in cut series of
# diamonds DataFrame.
cut_counts = df['cut'].value_counts()
cut_counts
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
# 35. Write a Pandas program to compute a cross-tabulation of two Series in
# diamonds DataFrame.
cross_tab = pd.crosstab(df['cut'], df['color'])
cross_tab
# Out:
# color         D     E     F     G     H     I    J
# cut
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678
# Good        662   933   909   871   702   522  307
# Fair        163   224   312   314   303   175  119

# %%
# 36. Write a Pandas program to calculate various summary statistics of cut series
# of diamonds DataFrame.
df['cut'].describe()
# Out:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object

# %%
# 37. Write a Pandas program to create a histogram of the 'carat' Series
# (distribution of a numerical variable) of diamonds DataFrame.
df.head(2)
df['carat'].plot(kind='hist',edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# 38. Write a Pandas program to create a bar plot of the 'value_counts' for the 'cut'
# series of diamonds DataFrame.
cut_counts = df['cut'].value_counts()
cut_counts.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Frequency of Diamond Cuts')
plt.xlabel('Cut')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
#39. Write a Pandas program to create a DataFrame of booleans (True if missing,
# False if not missing) from diamonds DataFrame.
boolean_df = df.isnull()
print(boolean_df.head())
# Out:
#    carat    cut  color  clarity  depth  table  price      x      y      z
# 0  False  False  False    False  False  False  False  False  False  False
# 1  False  False  False    False  False  False  False  False  False  False
# 2  False  False  False    False  False  False  False  False  False  False
# 3  False  False  False    False  False  False  False  False  False  False
# 4  False  False  False    False  False  False  False  False  False  False

# %%
#40. Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame.
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#41. Write a Pandas program to check the number of rows and columns and drop
# those row if 'any' values are missing in a row of diamonds DataFrame.
no_of_rows_column = df.shape
print('(rows, column):',no_of_rows_column)
df.dropna()
# Out:
# (rows, column): (53940, 10)
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#42. Write a Pandas program to drop a row if any or all values in a row are
#missing of diamonds DataFrame on two specific columns.
df.dropna(subset=['cut', 'color'],how='any')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# 43. Write a Pandas program to set an existing column as the index of diamonds DataFrame.
df.set_index('carat')
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21     Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29     Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31        Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...          ...   ...     ...    ...    ...    ...   ...   ...   ...
# 0.72       Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 0.72        Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 0.70   Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 0.86     Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 0.75       Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
# 44. Write a Pandas program to set an existing column as the index of diamonds
# DataFrame and restore the index name, and move the index back to a column.
df.index.name = 'cut_index'
print(df.head())
# Out:
#            carat      cut color clarity  depth  table  price     x     y     z
# cut_index
# 0           0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1           0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2           0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3           0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4           0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# reset
df_reset = df.reset_index()
print(df_reset.head())
# Out:
#    cut_index  carat      cut color clarity  depth  table  price     x     y  \
# 0          0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
#45. Write a Pandas program to access a specified Series index and the Series values of diamonds DataFrame.
cut_series = df['cut']
print(cut_series.index)
print("Series Values:")
print(cut_series.values[:10])
# Out:
# RangeIndex(start=0, stop=53940, step=1, name='cut_index')
# Series Values:
# ['Ideal', 'Premium', 'Good', 'Premium', 'Good', 'Very Good', 'Very Good', 'Very Good', 'Fair', 'Very Good']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
#46. Write a Pandas program to sort a Series by its values and index of diamonds DataFrame.
print('sort by index:\n',df.sort_index(ascending=False))
print('sort by values:\n',df.sort_values(by='depth'))
# Out:
# sort by index:
#             carat        cut color clarity  depth  table  price     x     y  \
# cut_index
# 53939       0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
# 53938       0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53937       0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53936       0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53935       0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# ...          ...        ...   ...     ...    ...    ...    ...   ...   ...
# 4           0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# 3           0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 2           0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 1           0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 0           0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
#
#               z
# cut_index
# 53939      3.64
# 53938      3.74
# 53937      3.56
# 53936      3.61
# 53935      3.50
# ...         ...
# 4          2.75
# 3          2.63
# 2          2.31
# 1          2.31
# 0          2.43
#
# [53940 rows x 10 columns]
# sort by values:
#             carat    cut color clarity  depth  table  price     x     y     z
# cut_index
# 10377       1.09  Ideal     J     VS2   43.0   54.0   4778  6.53  6.55  4.12
# 4518        1.00   Fair     G     SI1   43.0   59.0   3634  6.32  6.27  3.97
# 6341        1.00   Fair     G     VS2   44.0   53.0   4032  6.31  6.24  4.12
# 16857       1.43   Fair     I     VS1   50.8   60.0   6727  7.73  7.25  3.93
# 36503       0.30   Fair     E    VVS2   51.0   67.0    945  4.67  4.62  2.37
# ...          ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53540       0.90   Fair     G     SI1   72.9   54.0   2691  5.74  5.67  4.16
# 46679       0.99   Fair     J      I1   73.6   60.0   1789  6.01  5.80  4.35
# 41918       1.03   Fair     E      I1   78.2   54.0   1262  5.72  5.59  4.42
# 52861       0.50   Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
# 52860       0.50   Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
#
# [53940 rows x 10 columns]

# %%
# 47. Write a Pandas program to calculate the multiply of length, width and depth for each cut of diamonds DataFrame.
df['volume'] = df['x'] * df['y'] * df['z']
df.groupby('cut')['volume'].mean()
# Out:
# C:\Users\PGCP-AI\AppData\Local\Temp\ipykernel_16732\2430096117.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('cut')['volume'].mean()
# cut
# Ideal        115.394912
# Premium      145.052128
# Very Good    130.999722
# Good         136.257267
# Fair         164.950549
# Name: volume, dtype: float64

# %%
#48. Write a Pandas program to concatenate the diamonds DataFrame with the 'color' Series.
color_series = df['color']
result = pd.concat([df, color_series], axis=1)

result.head()
# Out:
#            carat      cut color clarity  depth  table  price     x     y  \
# cut_index
# 0           0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#               z     volume color
# cut_index
# 0          2.43  38.202030     E
# 1          2.31  34.505856     E
# 2          2.31  38.076885     E
# 3          2.63  46.724580     I
# 4          2.75  51.917250     J

# %%
# 49. Write a Pandas program to read specified rows and all columns of diamonds
# DataFrame.
df.iloc[0:3,:]
# Out:
#            carat      cut color clarity  depth  table  price     x     y  \
# cut_index
# 0           0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
#
#               z     volume
# cut_index
# 0          2.43  38.202030
# 1          2.31  34.505856
# 2          2.31  38.076885

# %%
#50. Write a Pandas program to read rows 0, 5, 7 and all columns of diamonds DataFrame.
df.iloc[[0,5,7],:]
# Out:
#            carat        cut color clarity  depth  table  price     x     y  \
# cut_index
# 0           0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 5           0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96
# 7           0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11
#
#               z     volume
# cut_index
# 0          2.43  38.202030
# 5          2.48  38.693952
# 7          2.53  42.321081

# %%
# 51. Write a Pandas program to read rows 2 through 5 and all columns of diamonds DataFrame.
df.iloc[2:5,:]
# Out:
#            carat      cut color clarity  depth  table  price     x     y  \
# cut_index
# 2           0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#               z     volume
# cut_index
# 2          2.31  38.076885
# 3          2.63  46.724580
# 4          2.75  51.917250

# %%
# 52. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color' and 'price' of diamonds DataFrame.
df.loc[:2,['color','price']]
# Out:
#           color  price
# cut_index
# 0             E    326
# 1             E    326
# 2             E    327

# %%
# 53. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color' through 'price' (inclusive) of diamonds DataFrame.
df.loc[0:2,'color':'price']
# Out:
#           color clarity  depth  table  price
# cut_index
# 0             E     SI2   61.5   55.0    326
# 1             E     SI1   59.8   61.0    326
# 2             E     VS1   56.9   65.0    327

# %%
# 54. Write a Pandas program to read rows in which the 'cut' is 'Premium', column 'color' of diamonds DataFrame.
df[df['cut']=='Premium'][["cut","color"]]
# Out:
#                cut color
# cut_index
# 1          Premium     E
# 3          Premium     I
# 12         Premium     F
# 14         Premium     E
# 15         Premium     E
# ...            ...   ...
# 53928      Premium     E
# 53930      Premium     E
# 53931      Premium     F
# 53934      Premium     D
# 53938      Premium     H
#
# [13791 rows x 2 columns]

# %%
# 55. Write a Pandas program to read rows in positions 0 and 1, columns in positions 0 and 3 of diamonds DataFrame.
df.iloc[[0,1],[0,3]]
# Out:
#            carat clarity
# cut_index
# 0           0.23     SI2
# 1           0.21     SI1

# %%
# 56. Write a Pandas program to read rows in positions 0 through 4, columns in positions 1 through 4 of diamonds DataFrame.
df.iloc[0:5,1:5]
# Out:
#                cut color clarity  depth
# cut_index
# 0            Ideal     E     SI2   61.5
# 1          Premium     E     SI1   59.8
# 2             Good     E     VS1   56.9
# 3          Premium     I     VS2   62.4
# 4             Good     J     SI2   63.3

# %%
# 57. Write a Pandas program to read rows in positions 0 through 4 (exclusive) and all columns of diamonds DataFrame.
df.iloc[0:4,:]
# Out:
#            carat      cut color clarity  depth  table  price     x     y  \
# cut_index
# 0           0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
#
#               z     volume
# cut_index
# 0          2.43  38.202030
# 1          2.31  34.505856
# 2          2.31  38.076885
# 3          2.63  46.724580

# %%
# 58. Write a Pandas program to read rows 2 through 5 (inclusive), columns in positions 0 through 2 (exclusive) of diamonds DataFrame.
df.iloc[2:6,0:2]
# Out:
#            carat        cut
# cut_index
# 2           0.23       Good
# 3           0.29    Premium
# 4           0.31       Good
# 5           0.24  Very Good

# %%
# 59. Write a Pandas program to print a concise summary of diamonds DataFrame.
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z        volume
# count  53940.000000  53940.000000  53940.000000
# mean       5.734526      3.538734    129.849403
# std        1.142135      0.705699     78.245262
# min        0.000000      0.000000      0.000000
# 25%        4.720000      2.910000     65.136830
# 50%        5.710000      3.530000    114.808572
# 75%        6.540000      4.040000    170.842451
# max       58.900000     31.800000   3840.598060

# %%
# 60. Write a Pandas program to get the true memory usage by diamonds DataFrame.
memory_usage = df.memory_usage(deep=True).sum()
print(memory_usage)
# Out:
# 3615924

# %%
# 61. Write a Pandas program to calculate the memory usage for each Series (in bytes) of diamonds DataFrame.
memory_usage = df.memory_usage(deep=True)
memory_usage
# Out:
# Index         132
# carat      431520
# cut         54386
# color       54590
# clarity     54656
# depth      431520
# table      431520
# price      431520
# x          431520
# y          431520
# z          431520
# volume     431520
# dtype: int64

# %%
# 62. Write a Pandas program to get randomly sample rows from diamonds DataFrame.
df.sample()
# Out:
#            carat        cut color clarity  depth  table  price     x     y  \
# cut_index
# 49004       0.51  Very Good     F    VVS2   62.7   56.0   2051  5.11  5.13
#
#               z     volume
# cut_index
# 49004      3.21  84.147903

# %%
# 63. Write a Pandas program to get sample 75% of the diamonds DataFrame's
# rows without replacement and store the remaining 25% of the rows in another DataFrame.
diamonds_75 = df.sample(frac=0.75, random_state=42)
diamonds_25 = df.drop(diamonds_75.index)
print("75% sample shape:", diamonds_75.shape)
print("25% remaining shape:", diamonds_25.shape)
# Out:
# 75% sample shape: (40455, 11)
# 25% remaining shape: (13485, 11)

# %%
# 64. Write a Pandas program to read the diamonds DataFrame and detect duplicate color.
# Note: duplicated () function returns boolean Series denoting duplicate rows,
# optionally only considering certain columns.
duplicates = df['color'].duplicated()
print(duplicates.head(15))
duplicate_rows = df[df['color'].duplicated()]
print(duplicate_rows.head())
# Out:
# cut_index
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# Name: color, dtype: bool
#            carat        cut color clarity  depth  table  price     x     y  \
# cut_index
# 1           0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 5           0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96
# 6           0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98
# 8           0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78
#
#               z     volume
# cut_index
# 1          2.31  34.505856
# 2          2.31  38.076885
# 5          2.48  38.693952
# 6          2.47  38.830870
# 8          2.49  36.425214
