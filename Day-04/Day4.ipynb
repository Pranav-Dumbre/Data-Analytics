# %%
# Mean, Median, Mode
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
temperature = [30,31,29,30,32,31,30,29,30,31,30,32,31,30]
products_solds = [20,22,21,20,23,21,20,22,21,20,22,21,20,100]
df_temp = pd.DataFrame({'Temperature':temperature})
df_sales = pd.DataFrame({'Products solds':products_solds})

# %%
print('Temperature data')
print('Mean:',df_temp['Temperature'].mean())
print('Median:',df_temp['Temperature'].median())
print('Mode:',df_temp['Temperature'].mode()[0])
# Out:
# Temperature data
# Mean: 30.428571428571427
# Median: 30.0
# Mode: 30

# %%
print('Products sales data')
print('Mean:',df_sales['Products solds'].mean())
print('Median:',df_sales['Products solds'].median())
print('Mode:',df_sales['Products solds'].mode()[0])
# Out:
# Products sales data
# Mean: 26.642857142857142
# Median: 21.0
# Mode: 20

# %%
fig, axes = plt.subplots(1,2,figsize=(10,5))
axes[0].boxplot(df_temp['Temperature'])
axes[0].set_title('Temperature (No outlier)')
axes[0].set_ylabel('Celcius')

axes[1].boxplot(df_sales['Products solds'])
axes[1].set_title('Products solds (No outlier)')
axes[1].set_ylabel('Units')

plt.tight_layout()
plt.show()

# %%
commute_time=[16,8,35,17,13,15,15,5,16,25,20,20,12,10]
plt.figure(figsize=(10,6))
sns.boxplot(data=commute_time,orient='h')
plt.title('Boxplot of commute times')
plt.xlabel('mins')
plt.show()

# %%
df = pd.read_csv('billionaires.csv')
df
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
finalworth=df['finalWorth']
skewness_finalworth = finalworth.skew()
kurtosis_finalworth = finalworth.kurt()
mean_finalworth = finalworth.mean()
median_finalworth = finalworth.median()
print(mean_finalworth,median_finalworth,skewness_finalworth,kurtosis_finalworth)
# Out:
# 4623.787878787879 2300.0 10.012367321086751 145.07368067526582

# %%
plt.figure(figsize=(8,6))
sns.histplot(finalworth,kde=True,bins=30)
plt.axvline(mean_finalworth,color='red',linestyle='--',
label = f'Mean:{mean_finalworth:.2f}')
plt.axvline(median_finalworth,color='black',linestyle='--',
label = f'Median:{median_finalworth:.2f}')
plt.title(f'Distribution of final worth\nSkewness:{skewness_finalworth:.2f},kurtosis:{kurtosis_finalworth:.2f}')
plt.xlabel('Final Worth')
plt.ylabel('Frequency')
plt.legend()
plt.tight_layout()
plt.show()
