# %%
# linear regression
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('salary.csv')
x=df[['YearsExperience']]
y=df['Salary']

#step2: split data into traing and testing test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20,random_state=0)

#step3: fit simple linear regression to training data
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)

#step4: make prediction
y_pred = model.predict(x_test)

#step5: visualize test set results
plt.scatter(x_test, y_test, color='red')
plt.plot(x_train,model.predict(x_train), color='blue')
plt.title('Salary vs Experience(Test test)')
plt.xlabel("year of experience")
plt.ylabel('Salary')
plt.show()

#step6: make new prediction
new_x_values_df = pd.DataFrame({'YearsExperience':[1,3,5,8,12,15,20,25]})
new_y_pred = model.predict(new_x_values_df)
print('\nPredictions for new excperience values(1,3,5,8,12,15,20,25):\n',new_y_pred)

#step7-model evaluation
from sklearn.metrics import mean_absolute_error,mean_squred_error,r2_score

mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,yy_pred)

print('\nModel evaluation metrics:')
print('\nMean absolute error:',mae)
print('\nMean squared error:',mse)
print('\nR2 score:',r2)
# Out:
# Predictions for new excperience values(1,3,5,8,12,15,20,25):
#  [ 36092.67427736  54717.82453082  73342.97478427 101280.70016446
#  138531.00067138 166468.72605157 213031.60168521 259594.47731886]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 34
#      31 print('\nPredictions for new excperience values(1,3,5,8,12,15,20,25):\n',new_y_pred)
#      33 #step7-model evaluation
# ---> 34 from sklearn.metrics import mean_absolute_error,mean_squred_error,r2_score
#      36 mae=mean_absolute_error(y_test,y_pred)
#      37 mse=mean_squared_error(y_test,y_pred)
#
# ImportError: cannot import name 'mean_squred_error' from 'sklearn.metrics' (C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\__init__.py)
